# %% [markdown]
# ## Data set summary
# #### FIFA football simulation data published by Electronic Arts.

# %%
import pandas as pd

# %% [markdown]
# ### Data Import

# %%
fifa = pd.read_csv('C:\\Users\\klegesse\\Desktop\\New folder\\Fifa 23 Players Data.csv')
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     18539 non-null  object
#  1   Full Name                    18539 non-null  object
#  2   Overall                      18539 non-null  int64
#  3   Potential                    18539 non-null  int64
#  4   Value(in Euro)               18539 non-null  int64
#  5   Positions Played             18539 non-null  object
#  6   Best Position                18539 non-null  object
#  7   Nationality                  18539 non-null  object
#  8   Image Link                   18539 non-null  object
#  9   Age                          18539 non-null  int64
#  10  Height(in cm)                18539 non-null  int64
#  11  Weight(in kg)                18539 non-null  int64
#  12  TotalStats                   18539 non-null  int64
# ...

# %%
fifa.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %% [markdown]
# ### Standard mathematical description

# %%
fifa.describe()
# Out:
#             Overall     Potential  Value(in Euro)           Age  \
# count  18539.000000  18539.000000    1.853900e+04  18539.000000
# mean      65.852042     71.016668    2.875461e+06     25.240412
# std        6.788353      6.192866    7.635129e+06      4.718163
# min       47.000000     48.000000    0.000000e+00     16.000000
# 25%       62.000000     67.000000    4.750000e+05     21.000000
# 50%       66.000000     71.000000    1.000000e+06     25.000000
# 75%       70.000000     75.000000    2.000000e+06     29.000000
# max       91.000000     95.000000    1.905000e+08     44.000000
#
#        Height(in cm)  Weight(in kg)    TotalStats     BaseStats  \
# count   18539.000000   18539.000000  18539.000000  18539.000000
# mean      181.550839      75.173904   1602.114569    357.946221
# std         6.858097       7.013593    273.160237     39.628259
# min       155.000000      49.000000    759.000000    224.000000
# 25%       177.000000      70.000000   1470.000000    331.000000
# ...

# %% [markdown]
# ### Description of 'Age'

# %%
fifa[['Age']].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23568\2911135134.py in <module>
# ----> 1 fifa[['Age']].describe()
#
# NameError: name 'fifa' is not defined

# %% [markdown]
# ### National team representations

# %%
fifa[['National Team Name']].value_counts()
# Out:
# National Team Name
# -                      17722
# Czech Republic            28
# Morocco                   26
# Scotland                  25
# Mexico                    25
# United States             24
# Austria                   24
# Ukraine                   24
# Croatia                   24
# Republic of Ireland       24
# Ghana                     24
# Spain                     23
# Romania                   23
# Qatar                     23
# Portugal                  23
# Poland                    23
# New Zealand               23
# Netherlands               23
# Italy                     23
# Argentina                 23
# Finland                   23
# Belgium                   23
# Brazil                    23
# Canada                    23
# China PR                  23
# Iceland                   23
# England                   23
# France                    23
# Germany                   23
# Hungary                   23
# Wales                     23
# ...

# %% [markdown]
# ### Percentage representation

# %%
fifa[['National Team Name']].value_counts(normalize=True)
# Out:
# National Team Name
# -                      0.955931
# Czech Republic         0.001510
# Morocco                0.001402
# Scotland               0.001349
# Mexico                 0.001349
# United States          0.001295
# Austria                0.001295
# Ukraine                0.001295
# Croatia                0.001295
# Republic of Ireland    0.001295
# Ghana                  0.001295
# Spain                  0.001241
# Romania                0.001241
# Qatar                  0.001241
# Portugal               0.001241
# Poland                 0.001241
# New Zealand            0.001241
# Netherlands            0.001241
# Italy                  0.001241
# Argentina              0.001241
# Finland                0.001241
# Belgium                0.001241
# Brazil                 0.001241
# Canada                 0.001241
# China PR               0.001241
# Iceland                0.001241
# England                0.001241
# France                 0.001241
# ...

# %% [markdown]
# ### Average age

# %%
fifa[['Age']].mean()
# Out:
# Age    25.240412
# dtype: float64

# %% [markdown]
# ### Group level aggregations

# %%
fifa.groupby('Club Name')[['Age']].mean()
# Out:
#                                  Age
# Club Name
# 1. FC Heidenheim 1846      24.642857
# 1. FC Kaiserslautern       25.866667
# 1. FC Köln                 24.322581
# 1. FC Magdeburg            24.200000
# 1. FC Nürnberg             24.285714
# ...                              ...
# Ümraniyespor               27.444444
# İstanbul Başakşehir FK     28.160000
# İstanbulspor               25.240000
# İttifak Holding Konyaspor  27.192308
# Śląsk Wrocław              23.821429
#
# [679 rows x 1 columns]

# %%
fifa.groupby('Club Name')[['Age']].mean().sort_values(by = 'Age', ascending=False)
# Out:
#                                    Age
# Club Name
# América Futebol Clube        29.800000
# Club Libertad                29.750000
# Shanghai Shenhua FC          29.250000
# Incheon United FC            29.107143
# Junior FC                    29.041667
# ...                                ...
# Borussia Dortmund II         21.720000
# Villarreal Club de Fútbol B  21.266667
# UCD AFC                      20.954545
# SC Freiburg II               20.925926
# FC Nordsjælland              20.607143
#
# [679 rows x 1 columns]

# %%
fifa.groupby('Club Name')[['Age']].agg(['mean','median','min','max'])
# Out:
#                                  Age
#                                 mean median min max
# Club Name
# 1. FC Heidenheim 1846      24.642857   24.5  17  35
# 1. FC Kaiserslautern       25.866667   25.0  19  36
# 1. FC Köln                 24.322581   24.0  18  32
# 1. FC Magdeburg            24.200000   24.5  18  33
# 1. FC Nürnberg             24.285714   24.0  17  33
# ...                              ...    ...  ..  ..
# Ümraniyespor               27.444444   27.0  19  37
# İstanbul Başakşehir FK     28.160000   30.0  16  36
# İstanbulspor               25.240000   24.0  17  35
# İttifak Holding Konyaspor  27.192308   27.0  18  34
# Śląsk Wrocław              23.821429   23.0  17  30
#
# [679 rows x 4 columns]
